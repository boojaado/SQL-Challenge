# %%
## Booth office hours

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import inspect, create_engine

# %%
# https://stackoverflow.com/a/42587012
HOSTNAME = "localhost"
PORT = 5432
DATABASE = "SQL_Challenge"
USERNAME = "postgres"
PASSWORD = "password"

path = f'postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOSTNAME}:{PORT}/{DATABASE}'
print(path)
# Out:
# postgresql+psycopg2://postgres:password@localhost:5432/SQL_Challenge

# %%
# Create engine
engine = create_engine(path)

# %%
inspector = inspect(engine)

for table in inspector.get_table_names():
    columns = inspector.get_columns(table)
    print(table)
    print()
    for column in columns:
        print(column["name"], column["type"])
        
        display(pd.DataFrame(columns))
        
        print()
# Out:
# titles
#
# ID INTEGER
#            name         type  nullable                               default  \
# 0            ID      INTEGER     False  nextval('"titles_ID_seq"'::regclass)
# 1      title_id  VARCHAR(10)     False                                  None
# 2         title  VARCHAR(50)     False                                  None
# 3  last_updated    TIMESTAMP     False                        LOCALTIMESTAMP
#
#    autoincrement comment
# 0           True    None
# 1          False    None
# 2          False    None
# 3          False    None
# title_id VARCHAR(10)
#            name         type  nullable                               default  \
# 0            ID      INTEGER     False  nextval('"titles_ID_seq"'::regclass)
# 1      title_id  VARCHAR(10)     False                                  None
# 2         title  VARCHAR(50)     False                                  None
# 3  last_updated    TIMESTAMP     False                        LOCALTIMESTAMP
#
#    autoincrement comment
# 0           True    None
# 1          False    None
# 2          False    None
# 3          False    None
# title VARCHAR(50)
#            name         type  nullable                               default  \
# 0            ID      INTEGER     False  nextval('"titles_ID_seq"'::regclass)
# 1      title_id  VARCHAR(10)     False                                  None
# 2         title  VARCHAR(50)     False                                  None
# 3  last_updated    TIMESTAMP     False                        LOCALTIMESTAMP
#
#    autoincrement comment
# 0           True    None
# 1          False    None
# 2          False    None
# 3          False    None
# last_updated TIMESTAMP
#            name         type  nullable                               default  \
# 0            ID      INTEGER     False  nextval('"titles_ID_seq"'::regclass)
# 1      title_id  VARCHAR(10)     False                                  None
# 2         title  VARCHAR(50)     False                                  None
# 3  last_updated    TIMESTAMP     False                        LOCALTIMESTAMP
#
#    autoincrement comment
# 0           True    None
# 1          False    None
# 2          False    None
# 3          False    None
# employees
#
# ID INTEGER
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# emp_no INTEGER
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# emp_title_id VARCHAR(10)
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# birth_date DATE
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# first_name VARCHAR(100)
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# last_name VARCHAR(100)
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# gender VARCHAR(1)
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# hire_date DATE
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# last_updated TIMESTAMP
#            name          type  nullable  \
# 0            ID       INTEGER     False
# 1        emp_no       INTEGER     False
# 2  emp_title_id   VARCHAR(10)     False
# 3    birth_date          DATE     False
# 4    first_name  VARCHAR(100)     False
# 5     last_name  VARCHAR(100)     False
# 6        gender    VARCHAR(1)     False
# 7     hire_date          DATE     False
# 8  last_updated     TIMESTAMP     False
#
#                                    default  autoincrement comment
# 0  nextval('"employees_ID_seq"'::regclass)           True    None
# 1                                     None          False    None
# 2                                     None          False    None
# 3                                     None          False    None
# 4                                     None          False    None
# 5                                     None          False    None
# 6                                     None          False    None
# 7                                     None          False    None
# 8                           LOCALTIMESTAMP          False    None
# departments
#
# ID INTEGER
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1       dept_no  VARCHAR(10)     False
# 2     dept_name  VARCHAR(50)     False
# 3  last_updated    TIMESTAMP     False
#
#                                      default  autoincrement comment
# 0  nextval('"departments_ID_seq"'::regclass)           True    None
# 1                                       None          False    None
# 2                                       None          False    None
# 3                             LOCALTIMESTAMP          False    None
# dept_no VARCHAR(10)
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1       dept_no  VARCHAR(10)     False
# 2     dept_name  VARCHAR(50)     False
# 3  last_updated    TIMESTAMP     False
#
#                                      default  autoincrement comment
# 0  nextval('"departments_ID_seq"'::regclass)           True    None
# 1                                       None          False    None
# 2                                       None          False    None
# 3                             LOCALTIMESTAMP          False    None
# dept_name VARCHAR(50)
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1       dept_no  VARCHAR(10)     False
# 2     dept_name  VARCHAR(50)     False
# 3  last_updated    TIMESTAMP     False
#
#                                      default  autoincrement comment
# 0  nextval('"departments_ID_seq"'::regclass)           True    None
# 1                                       None          False    None
# 2                                       None          False    None
# 3                             LOCALTIMESTAMP          False    None
# last_updated TIMESTAMP
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1       dept_no  VARCHAR(10)     False
# 2     dept_name  VARCHAR(50)     False
# 3  last_updated    TIMESTAMP     False
#
#                                      default  autoincrement comment
# 0  nextval('"departments_ID_seq"'::regclass)           True    None
# 1                                       None          False    None
# 2                                       None          False    None
# 3                             LOCALTIMESTAMP          False    None
# salaries
#
# ID INTEGER
#            name       type  nullable                                 default  \
# 0            ID    INTEGER     False  nextval('"salaries_ID_seq"'::regclass)
# 1        emp_no    INTEGER     False                                    None
# 2        salary    INTEGER     False                                    None
# 3  last_updated  TIMESTAMP     False                          LOCALTIMESTAMP
#
#    autoincrement comment
# 0           True    None
# 1          False    None
# 2          False    None
# 3          False    None
# emp_no INTEGER
#            name       type  nullable                                 default  \
# 0            ID    INTEGER     False  nextval('"salaries_ID_seq"'::regclass)
# 1        emp_no    INTEGER     False                                    None
# 2        salary    INTEGER     False                                    None
# 3  last_updated  TIMESTAMP     False                          LOCALTIMESTAMP
#
#    autoincrement comment
# 0           True    None
# 1          False    None
# 2          False    None
# 3          False    None
# salary INTEGER
#            name       type  nullable                                 default  \
# 0            ID    INTEGER     False  nextval('"salaries_ID_seq"'::regclass)
# 1        emp_no    INTEGER     False                                    None
# 2        salary    INTEGER     False                                    None
# 3  last_updated  TIMESTAMP     False                          LOCALTIMESTAMP
#
#    autoincrement comment
# 0           True    None
# 1          False    None
# 2          False    None
# 3          False    None
# last_updated TIMESTAMP
#            name       type  nullable                                 default  \
# 0            ID    INTEGER     False  nextval('"salaries_ID_seq"'::regclass)
# 1        emp_no    INTEGER     False                                    None
# 2        salary    INTEGER     False                                    None
# 3  last_updated  TIMESTAMP     False                          LOCALTIMESTAMP
#
#    autoincrement comment
# 0           True    None
# 1          False    None
# 2          False    None
# 3          False    None
# dept_emp
#
# ID INTEGER
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1        emp_no      INTEGER     False
# 2       dept_no  VARCHAR(10)     False
# 3  last_updated    TIMESTAMP     False
#
#                                   default  autoincrement comment
# 0  nextval('"dept_emp_ID_seq"'::regclass)           True    None
# 1                                    None          False    None
# 2                                    None          False    None
# 3                          LOCALTIMESTAMP          False    None
# emp_no INTEGER
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1        emp_no      INTEGER     False
# 2       dept_no  VARCHAR(10)     False
# 3  last_updated    TIMESTAMP     False
#
#                                   default  autoincrement comment
# 0  nextval('"dept_emp_ID_seq"'::regclass)           True    None
# 1                                    None          False    None
# 2                                    None          False    None
# 3                          LOCALTIMESTAMP          False    None
# dept_no VARCHAR(10)
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1        emp_no      INTEGER     False
# 2       dept_no  VARCHAR(10)     False
# 3  last_updated    TIMESTAMP     False
#
#                                   default  autoincrement comment
# 0  nextval('"dept_emp_ID_seq"'::regclass)           True    None
# 1                                    None          False    None
# 2                                    None          False    None
# 3                          LOCALTIMESTAMP          False    None
# last_updated TIMESTAMP
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1        emp_no      INTEGER     False
# 2       dept_no  VARCHAR(10)     False
# 3  last_updated    TIMESTAMP     False
#
#                                   default  autoincrement comment
# 0  nextval('"dept_emp_ID_seq"'::regclass)           True    None
# 1                                    None          False    None
# 2                                    None          False    None
# 3                          LOCALTIMESTAMP          False    None
# dept_manager
#
# ID INTEGER
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1       dept_no  VARCHAR(10)     False
# 2        emp_no      INTEGER     False
# 3  last_updated    TIMESTAMP     False
#
#                                       default  autoincrement comment
# 0  nextval('"dept_manager_ID_seq"'::regclass)           True    None
# 1                                        None          False    None
# 2                                        None          False    None
# 3                              LOCALTIMESTAMP          False    None
# dept_no VARCHAR(10)
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1       dept_no  VARCHAR(10)     False
# 2        emp_no      INTEGER     False
# 3  last_updated    TIMESTAMP     False
#
#                                       default  autoincrement comment
# 0  nextval('"dept_manager_ID_seq"'::regclass)           True    None
# 1                                        None          False    None
# 2                                        None          False    None
# 3                              LOCALTIMESTAMP          False    None
# emp_no INTEGER
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1       dept_no  VARCHAR(10)     False
# 2        emp_no      INTEGER     False
# 3  last_updated    TIMESTAMP     False
#
#                                       default  autoincrement comment
# 0  nextval('"dept_manager_ID_seq"'::regclass)           True    None
# 1                                        None          False    None
# 2                                        None          False    None
# 3                              LOCALTIMESTAMP          False    None
# last_updated TIMESTAMP
#            name         type  nullable  \
# 0            ID      INTEGER     False
# 1       dept_no  VARCHAR(10)     False
# 2        emp_no      INTEGER     False
# 3  last_updated    TIMESTAMP     False
#
#                                       default  autoincrement comment
# 0  nextval('"dept_manager_ID_seq"'::regclass)           True    None
# 1                                        None          False    None
# 2                                        None          False    None
# 3                              LOCALTIMESTAMP          False    None

# %%
query = '''
        Select 
        e.emp_no,
        s.salary
        From 
            employees e 
            join salaries s on e.emp_no = s.emp_no;
        '''
conn = engine.connect ()
salary = pd.read_sql (query, conn)
salary.head()
# Out:
#    emp_no  salary
# 0   57444   48973
# 1   13616   40000
# 2  240129   43548
# 3  427958   63377
# 4   35916   40000

# %%
#To create histogram 

x = salary.salary
plt.figure(figsize=(12,8))
plt.hist(x, density=False, bins=10)
plt.ylabel('Salary Counts')
plt.xlabel('Salary');

# %%
#salary by title query
query = '''
        Select t.title,
        avg(s.salary) as avgSalary
        From 
            employees e 
            join salaries s on e.emp_no = s.emp_no
            join titles t on e.emp_title_id = t.title_id
        group by 
        t.title
        order by 
        avgSalary desc
        '''
conn = engine.connect ()
df = pd.read_sql (query, conn)
df.head()
# Out:
#                 title     avgsalary
# 0        Senior Staff  58550.172704
# 1               Staff  58465.382850
# 2             Manager  51531.041667
# 3    Technique Leader  48582.896092
# 4  Assistant Engineer  48564.434447

# %%
# To create bar graph for itle and salary

plt.figure(figsize=(12,8))
plt.bar(df.title, df.avgsalary)
plt.xticks(rotation = 90)
plt.title('Title Average Salary')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %%
# Close connection
conn.close ()
engine.dispose()
